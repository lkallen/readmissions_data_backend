# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

df = pd.read_pickle('coef_clean_two.pkl')

feature_cols = [
    'insurance_type',
    'prev_readmit_group',
    'los_group',
    'dc_location',
    'primary_dx_tier',
    'age_bin'
]
df[feature_cols] = df[feature_cols].astype('category')

X = df[feature_cols]
y = df['label']

X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42
)

model = LogisticRegression(max_iter=500)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.825625

# %%
import joblib

joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
import joblib

joblib.dump(X_train.columns.tolist(), "columns.pkl")
# Out:
# ['columns.pkl']

# %%
import joblib

joblib.dump(0.50, "threshold.pkl")
# Out:
# ['threshold.pkl']

# %%
import joblib

model_test = joblib.load("model.pkl")
columns_test = joblib.load("columns.pkl")
threshold_test = joblib.load("threshold.pkl")

model_test, columns_test[:3], threshold_test
# Out:
# (LogisticRegression(max_iter=500),
#  ['insurance_type_Private',
#   'insurance_type_Uninsured',
#   'prev_readmit_group_1'],
#  0.5)

# %%
df[feature_cols].nunique()
# Out:
# insurance_type        3
# prev_readmit_group    3
# los_group             3
# dc_location           2
# primary_dx_tier       2
# age_bin               3
# dtype: int64

# %%
for col in feature_cols:
    print(col)
    print(df[col].unique())
# Out:
# insurance_type
# ['Medicare/Medicaid', 'Private', 'Uninsured']
# Categories (3, str): ['Medicare/Medicaid', 'Private', 'Uninsured']
# prev_readmit_group
# [1, 2, 0]
# Categories (3, int64): [0, 1, 2]
# los_group
# ['6 to 8', '9+', '5 or less']
# Categories (3, str): ['5 or less', '6 to 8', '9+']
# dc_location
# ['HH/SNF', 'Home/Rehab']
# Categories (2, str): ['HH/SNF', 'Home/Rehab']
# primary_dx_tier
# ['lower', 'higher']
# Categories (2, str): ['higher', 'lower']
# age_bin
# [2.0, 3.0, 1.0, NaN]
# Categories (3, float64): [1.0, 2.0, 3.0]
